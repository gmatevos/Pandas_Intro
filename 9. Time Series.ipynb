# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# # Time/date Overview

# %% [markdown]
# Converting string, np.datetime and default python datetime to pandas date time

# %%
dti = pd.to_datetime(['1/1/2018', np.datetime64('2018-01-01'),
   ...:                       datetime.datetime(2018, 1, 1)])

dti
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-01', '2018-01-01'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# Generating a sequence

# %%
idx = pd.date_range('2020-1-1',periods=5,freq='M')
idx
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts=pd.DataFrame(range(len(idx)),index=idx,columns=['number'])
ts
# Out:
#             number
# 2020-01-31       0
# 2020-02-29       1
# 2020-03-31       2
# 2020-04-30       3
# 2020-05-31       4

# %%
ts.resample('D').mean()
# Out:
#             number
# 2020-01-31     0.0
# 2020-02-01     NaN
# 2020-02-02     NaN
# 2020-02-03     NaN
# 2020-02-04     NaN
# ...            ...
# 2020-05-27     NaN
# 2020-05-28     NaN
# 2020-05-29     NaN
# 2020-05-30     NaN
# 2020-05-31     4.0
#
# [122 rows x 1 columns]

# %% [markdown]
# Various built in functionalities

# %%
ts['Day of the Week']=ts.index.day_name().tolist()
ts
# Out:
#             number Day of the Week
# 2020-01-31       0          Friday
# 2020-02-29       1        Saturday
# 2020-03-31       2         Tuesday
# 2020-04-30       3        Thursday
# 2020-05-31       4          Sunday

# %%
friday=ts.index[0]
print(friday)
print(friday.day_name())
# Out:
# 2020-01-31 00:00:00
# Friday

# %% [markdown]
# adding a day to date

# %%
saturday = friday + pd.Timedelta('1 d')
print(saturday)
print(saturday.day_name())
# Out:
# 2020-02-01 00:00:00
# Saturday

# %% [markdown]
# offseting to business days

# %%
tuesday = friday + pd.offsets.BDay(2)
print(tuesday)
print(tuesday.day_name())
# Out:
# 2020-02-04 00:00:00
# Tuesday

# %% [markdown]
# # Timestamps vs Time Spans

# %%
pd.Timestamp('2020/1/5')
# Out:
# Timestamp('2020-01-05 00:00:00')

# %%
pd.Timestamp(2012,12,25)
# Out:
# Timestamp('2012-12-25 00:00:00')

# %%
pd.Period('2011-1')
# Out:
# Period('2011-01', 'M')

# %%
pd.Period('2015-05',freq='D')
# Out:
# Period('2015-05-01', 'D')

# %%
dates = [pd.Timestamp('2012-05-01'),
   ....:          pd.Timestamp('2012-05-02'),
   ....:          pd.Timestamp('2012-05-03')]


ts=pd.Series(np.random.randint(100,size=3),index=dates)
ts
# Out:
# 2012-05-01    55
# 2012-05-02    80
# 2012-05-03    21
# dtype: int32

# %%
type(ts.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
periods = [pd.Period('2012-01'), pd.Period('2012-02'), pd.Period('2012-03')]
ts = pd.Series(np.random.rand(3),index=periods)
ts
# Out:
# 2012-01    0.668325
# 2012-02    0.009027
# 2012-03    0.493089
# Freq: M, dtype: float64

# %%
ts.index
# Out:
# PeriodIndex(['2012-01', '2012-02', '2012-03'], dtype='period[M]', freq='M')

# %%
pd.to_datetime(pd.Series(['2009-3/1','1.15.20']))
# Out:
# 0   2009-03-01
# 1   2020-01-15
# dtype: datetime64[ns]

# %% [markdown]
# # Assembling datetime from multiple DF columns

# %%
df = pd.DataFrame({'year': [2015, 2016],
   ....:                    'month': [2, 3],
   ....:                    'day': [4, 5],
   ....:                    'hour': [2, 3]})

pd.to_datetime(df)
# Out:
# 0   2015-02-04 02:00:00
# 1   2016-03-05 03:00:00
# dtype: datetime64[ns]

# %%
df['ts']=pd.to_datetime(df.iloc[:,:-1])
df
# Out:
#    year  month  day  hour         ts
# 0  2015      2    4     2 2015-02-04
# 1  2016      3    5     3 2016-03-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    2 non-null      int64
#  1   month   2 non-null      int64
#  2   day     2 non-null      int64
#  3   hour    2 non-null      int64
#  4   ts      2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 208.0 bytes

# %%
pd.bdate_range('1/1/2020','1/1/2025',freq='M')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#                '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %% [raw]
# pd.to_datetime() - converts data to datetime
# pd.date_range() - creates a series with specified range
#
# pd.to_timedelta()
# pd.timedelta_range()
#
# df.A.resample() - converts between time steps
# pd.Timedelta() - creates a step for time manipulation
# pd.offsets.BDay() - gets business days
# pd.bdate_range(start, end) - creates a business day range
#
# pd.Timestamp() - creates a date stamp (point in time)
# pd.Period() - creates a time span (doesn't have to have a day in date)

# %%
pd.date_range('1/1/2020','1/1/2025',freq='M')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#                '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.Timedelta('2020/1/1',unit='M')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-095b31d58ea7> in <module>
# ----> 1 pd.Timedelta('2020/1/1',unit='M')
#
# pandas\_libs\tslibs\timedeltas.pyx in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ValueError: Units 'M' and 'Y' are no longer supported, as they do not represent unambiguous timedelta values durations.

# %%
df=pd.DataFrame(np.random.randint(100,size=(50,2)),columns=list('AB'))
df
# Out:
#      A   B
# 0   21   6
# 1   19  79
# 2   17  42
# 3   27  16
# 4   70  61
# 5   14  41
# 6   42  33
# 7   96  80
# 8   47   8
# 9   45  80
# 10  43  71
# 11  75   9
# 12  73  55
# 13  94  73
# 14  63  15
# 15  33  66
# 16  61   2
# 17  93  31
# 18  18   0
# 19  14  28
# 20  29  68
# 21   2  22
# 22  97  61
# 23  37   1
# 24  78  30
# 25  14  23
# 26  10  38
# 27  80  19
# 28  85  74
# 29  11  78
# 30   0  75
# 31  55  25
# 32  45  68
# 33  19  88
# 34  39  26
# 35  84  70
# 36  14  61
# 37  90  28
# 38  82  24
# 39  30  85
# 40  83  93
# 41  57   4
# 42  49  20
# 43  54  26
# 44  33  42
# 45  19  75
# 46  56  37
# 47  58  39
# 48  62  46
# 49  59  39

# %%
df['time']=pd.date_range('1/1/2002',freq='M',periods=50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       50 non-null     int32
#  1   B       50 non-null     int32
#  2   time    50 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int32(2)
# memory usage: 928.0 bytes

# %%
df['dateName']=df.time.dt.day_name()

# %%
df['offset']=df.time + pd.offsets.BDay(3)
df['offsetName']=df.offset.dt.day_name()
df
# Out:
#      A   B       time   dateName     offset offsetName
# 0   21   6 2002-01-31   Thursday 2002-02-05    Tuesday
# 1   19  79 2002-02-28   Thursday 2002-03-05    Tuesday
# 2   17  42 2002-03-31     Sunday 2002-04-03  Wednesday
# 3   27  16 2002-04-30    Tuesday 2002-05-03     Friday
# 4   70  61 2002-05-31     Friday 2002-06-05  Wednesday
# 5   14  41 2002-06-30     Sunday 2002-07-03  Wednesday
# 6   42  33 2002-07-31  Wednesday 2002-08-05     Monday
# 7   96  80 2002-08-31   Saturday 2002-09-04  Wednesday
# 8   47   8 2002-09-30     Monday 2002-10-03   Thursday
# 9   45  80 2002-10-31   Thursday 2002-11-05    Tuesday
# 10  43  71 2002-11-30   Saturday 2002-12-04  Wednesday
# 11  75   9 2002-12-31    Tuesday 2003-01-03     Friday
# 12  73  55 2003-01-31     Friday 2003-02-05  Wednesday
# 13  94  73 2003-02-28     Friday 2003-03-05  Wednesday
# 14  63  15 2003-03-31     Monday 2003-04-03   Thursday
# 15  33  66 2003-04-30  Wednesday 2003-05-05     Monday
# 16  61   2 2003-05-31   Saturday 2003-06-04  Wednesday
# 17  93  31 2003-06-30     Monday 2003-07-03   Thursday
# 18  18   0 2003-07-31   Thursday 2003-08-05    Tuesday
# 19  14  28 2003-08-31     Sunday 2003-09-03  Wednesday
# 20  29  68 2003-09-30    Tuesday 2003-10-03     Friday
# 21   2  22 2003-10-31     Friday 2003-11-05  Wednesday
# 22  97  61 2003-11-30     Sunday 2003-12-03  Wednesday
# 23  37   1 2003-12-31  Wednesday 2004-01-05     Monday
# 24  78  30 2004-01-31   Saturday 2004-02-04  Wednesday
# 25  14  23 2004-02-29     Sunday 2004-03-03  Wednesday
# 26  10  38 2004-03-31  Wednesday 2004-04-05     Monday
# 27  80  19 2004-04-30     Friday 2004-05-05  Wednesday
# 28  85  74 2004-05-31     Monday 2004-06-03   Thursday
# 29  11  78 2004-06-30  Wednesday 2004-07-05     Monday
# 30   0  75 2004-07-31   Saturday 2004-08-04  Wednesday
# 31  55  25 2004-08-31    Tuesday 2004-09-03     Friday
# 32  45  68 2004-09-30   Thursday 2004-10-05    Tuesday
# 33  19  88 2004-10-31     Sunday 2004-11-03  Wednesday
# 34  39  26 2004-11-30    Tuesday 2004-12-03     Friday
# 35  84  70 2004-12-31     Friday 2005-01-05  Wednesday
# 36  14  61 2005-01-31     Monday 2005-02-03   Thursday
# 37  90  28 2005-02-28     Monday 2005-03-03   Thursday
# 38  82  24 2005-03-31   Thursday 2005-04-05    Tuesday
# 39  30  85 2005-04-30   Saturday 2005-05-04  Wednesday
# 40  83  93 2005-05-31    Tuesday 2005-06-03     Friday
# 41  57   4 2005-06-30   Thursday 2005-07-05    Tuesday
# 42  49  20 2005-07-31     Sunday 2005-08-03  Wednesday
# 43  54  26 2005-08-31  Wednesday 2005-09-05     Monday
# 44  33  42 2005-09-30     Friday 2005-10-05  Wednesday
# 45  19  75 2005-10-31     Monday 2005-11-03   Thursday
# 46  56  37 2005-11-30  Wednesday 2005-12-05     Monday
# 47  58  39 2005-12-31   Saturday 2006-01-04  Wednesday
# 48  62  46 2006-01-31    Tuesday 2006-02-03     Friday
# 49  59  39 2006-02-28    Tuesday 2006-03-03     Friday

# %%
df['year']=np.random.randint(2000,2021,size=(len(df)))
df['month']=np.random.randint(1,13,size=(len(df)))
df['day']=np.random.randint(1,28,size=(len(df)))

# %%
df.head()
# Out:
#     A   B       time  dateName     offset offsetName  year  month  day
# 0  21   6 2002-01-31  Thursday 2002-02-05    Tuesday  2006      5    3
# 1  19  79 2002-02-28  Thursday 2002-03-05    Tuesday  2005      7   15
# 2  17  42 2002-03-31    Sunday 2002-04-03  Wednesday  2004      2   27
# 3  27  16 2002-04-30   Tuesday 2002-05-03     Friday  2019      3    1
# 4  70  61 2002-05-31    Friday 2002-06-05  Wednesday  2016      1   27

# %%
df['combinedDate']=pd.to_datetime(df.iloc(axis=1)[-3:])

# %%
df.head()
# Out:
#     A   B       time  dateName     offset offsetName  year  month  day  \
# 0  21   6 2002-01-31  Thursday 2002-02-05    Tuesday  2006      5    3
# 1  19  79 2002-02-28  Thursday 2002-03-05    Tuesday  2005      7   15
# 2  17  42 2002-03-31    Sunday 2002-04-03  Wednesday  2004      2   27
# 3  27  16 2002-04-30   Tuesday 2002-05-03     Friday  2019      3    1
# 4  70  61 2002-05-31    Friday 2002-06-05  Wednesday  2016      1   27
#
#   combinedDate
# 0   2006-05-03
# 1   2005-07-15
# 2   2004-02-27
# 3   2019-03-01
# 4   2016-01-27

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   A             50 non-null     int32
#  1   B             50 non-null     int32
#  2   time          50 non-null     datetime64[ns]
#  3   dateName      50 non-null     object
#  4   offset        50 non-null     datetime64[ns]
#  5   offsetName    50 non-null     object
#  6   year          50 non-null     int32
#  7   month         50 non-null     int32
#  8   day           50 non-null     int32
#  9   combinedDate  50 non-null     datetime64[ns]
# dtypes: datetime64[ns](3), int32(5), object(2)
# memory usage: 3.1+ KB

# %%
df['dateoffset2']=df.combinedDate+pd.Timedelta(days=5)
df.head()
# Out:
#     A   B       time  dateName     offset offsetName  year  month  day  \
# 0  21   6 2002-01-31  Thursday 2002-02-05    Tuesday  2006      5    3
# 1  19  79 2002-02-28  Thursday 2002-03-05    Tuesday  2005      7   15
# 2  17  42 2002-03-31    Sunday 2002-04-03  Wednesday  2004      2   27
# 3  27  16 2002-04-30   Tuesday 2002-05-03     Friday  2019      3    1
# 4  70  61 2002-05-31    Friday 2002-06-05  Wednesday  2016      1   27
#
#   combinedDate dateoffset2
# 0   2006-05-03  2006-05-08
# 1   2005-07-15  2005-07-20
# 2   2004-02-27  2004-03-03
# 3   2019-03-01  2019-03-06
# 4   2016-01-27  2016-02-01

# %% [markdown]
# # Resample

# %%
rng=pd.date_range('1/1/2020',periods=100,freq='S')

ts = pd.Series(np.random.randint(0,550,len(rng)),index=rng)
ts
# Out:
# 2020-01-01 00:00:00    134
# 2020-01-01 00:00:01    446
# 2020-01-01 00:00:02     66
# 2020-01-01 00:00:03    169
# 2020-01-01 00:00:04    327
#                       ...
# 2020-01-01 00:01:35    531
# 2020-01-01 00:01:36    374
# 2020-01-01 00:01:37    536
# 2020-01-01 00:01:38    292
# 2020-01-01 00:01:39    314
# Freq: S, Length: 100, dtype: int32

# %%
ts.resample('5Min').sum()
# Out:
# 2020-01-01    27106
# Freq: 5T, dtype: int32
